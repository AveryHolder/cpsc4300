# %% [markdown]
# # Overview
#
# This notebook sets up the following directories for the final project.
# ```
# project
# ├── data
# ├── LICENSE
# ├── models
# ├── notebooks
# │   └── 0_setup_project_folders.ipynb
# ├── README.md
# ├── report
# │   ├── interim.md
# │   ├── proposal.md
# │   └── report.md
# └── src
# ```
#
# You are free to rename any the directory or add other directories. You can also switch the LICENSE to any other license type tha you prefer.

# %%
import os

basedir = os.path.dirname(os.getcwd())

subdirs = ['src', 'data', 'models']
for d in subdirs:
    full_path = os.path.join(basedir, d)
    if not os.path.exists(full_path):
        os.makedirs(full_path)

assert all([os.path.exists(os.path.join(basedir, d)) for d in subdirs])

# %%
# !tree ../
# Out:
# ../
# ├── cpsc6300
# │   └── rhew-holder-rodgers
# ├── data
# ├── LICENSE
# ├── List_of_Doggo_Names.csv
# ├── models
# ├── notebooks
# │   ├── 0_setup_project_folders.ipynb
# │   ├── Clean and Summarize Dog Data.ipynb
# │   ├── Dog_Breeds_With_Rankings.csv
# │   ├── List_of_Doggo_Names.csv
# │   └── Name_List.py
# ├── README.md
# ├── report
# │   ├── interim.md
# │   ├── proposal.md
# │   └── report.md
# ├── src
# └── untitled.txt
#
# 7 directories, 12 files

# %%
from bs4 import BeautifulSoup
import requests

# %%
'''First we are trying to get data from one page for one breed'''
url = 'https://dogtime.com/dog-breeds/border-collie'
url_html = requests.get(url)
soup = BeautifulSoup(url_html.text, 'html.parser')
print(type(soup))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
'''Using the BeuatifulSoup object we created above, we are parsing for characteristics and star quality associated with them on a scale of 1-5'''
# Out:
# 'Using the BeuatifulSoup object we created above, we are parsing for characteristics and star quality associated with them on a scale of 1-5'

# %%
'''We are creating lists for the attributes and star rankings of the Border Collie'''
# Out:
# 'We are creating lists for the attributes and star rankings of the Border Collie'

# %%
titles_html = soup.find_all('div', {'class':'characteristic-stars parent-characteristic'})
titles = []
star_ranks = []
for html_obj in titles_html:
    title = html_obj('h3', {'class': 'characteristic-title'})
    titles.append(title[0].string[1:])
    star_rank = html_obj('div', {'class': 'star'})
    star_rank[0] = star_rank[0]["class"]
    star_ranks.append(int(star_rank[0][1][-1]))
print(titles)
print(star_ranks)
# Out:
# ['Adaptability', 'All Around Friendliness', 'Health And Grooming Needs', 'Trainability', 'Physical Needs']
# [3, 4, 3, 4, 5]

# %%
'''Now we are going to make a function to automate this process with a lot of dog breeds'''
# Out:
# 'Now we are going to make a function to automate this process with a lot of dog breeds'

# %%
def get_url(dog_breed):
    return ('https://dogtime.com/dog-breeds/' + dog_breed)

# %%
'''test get_url function... file with dog breeds includes dashes in name'''
# Out:
# 'test get_url function... file with dog breeds includes dashes in name'

# %%
url_d = get_url('american-border-collie')
url_d
# Out:
# 'https://dogtime.com/dog-breeds/american-border-collie'

# %%
'''create function to get attributes and rankings based on url'''
# Out:
# 'create function to get attributes and rankings based on url'

# %%
import pandas as pd
def get_attributes(url):
    url_html = requests.get(url)
    soup = BeautifulSoup(url_html.text, 'html.parser')
    
    titles_html = soup.find_all('div', {'class':'characteristic-stars parent-characteristic'})
    titles = []
    star_ranks = []
    for html_obj in titles_html:
        title = html_obj('h3', {'class': 'characteristic-title'})
        titles.append(title[0].string[1:])
        star_rank = html_obj('div', {'class': 'star'})
        star_rank[0] = star_rank[0]["class"]
        star_ranks.append(star_rank[0][1][-1])
        
    attributes = pd.Series(index=titles, data=star_ranks, dtype = object)
    return attributes

# %%
'''test get attributes'''
# Out:
# 'test get attributes'

# %%
print(get_attributes(get_url('Border-collie')))
# Out:
# Adaptability                 3
# All Around Friendliness      4
# Health And Grooming Needs    3
# Trainability                 4
# Physical Needs               5
# dtype: object

# %%
'''Now we will use a function to generate a list of dog breeds'''
# Out:
# 'Now we will use a function to generate a list of dog breeds'

# %%
def get_list_of_names(csvFile):
    """
    This function reads in a list of names from a csv file 

    Args:
        csvFile: The csv file with the list of names

    Returns:
        listOfNames: Pandas Series of names
    """
    listOfNames = pd.read_csv(csvFile, index_col=False, header=0)
    

    # if(!listOfNames.len()):
    #     print("list of names did not import correctly") 
    #     return

    return listOfNames

# %%
'''now we will get the list of names using a CSV of names'''
# Out:
# 'now we will get the list of names using a CSV of names'

# %%
dog_df = get_list_of_names('List_of_Doggo_Names.csv')
dog_df.head(5)
dog_list = dog_df.Breeds.tolist()
dog_list
# Out:
# ['Afador',
#  'Affenhuahua',
#  'Affenpinscher',
#  'Afghan-Hound',
#  'Airedale-Terrier',
#  'Akbash',
#  'Akita',
#  'Akita-Chow',
#  'Akita-Pit',
#  'Akita-Shepherd',
#  'Alaskan-Klee-Kai',
#  'Alaskan-Malamute',
#  'American-Bulldog',
#  'American-English-Coonhound',
#  'American-Eskimo-Dog',
#  'American-Foxhound',
#  'American-Hairless-Terrier',
#  'American-Leopard-Hound',
#  'American-Pit-Bull-Terrier',
#  'American-Pugabull',
#  'American-Staffordshire-Terrier',
#  'American-Water-Spaniel',
#  'Anatolian-Shepherd-Dog',
#  'Appenzeller-Sennenhunde',
#  'Auggie',
#  'Aussiedoodle',
#  'Aussiepom',
#  'Australian-Cattle-Dog',
#  'Australian-Kelpie',
#  'Australian-Retriever',
#  'Australian-Shepherd',
#  'Australian-Shepherd-Husky',
#  'Australian-Shepherd-Lab-Mix',
#  'Australian-Shepherd-Pit-Bull-Mix',
#  'Australian-Stumpy-Tail-Cattle-Dog',
#  'Australian-Terrier',
#  'Azawakh',
#  'Barbet',
#  'Basenji',
#  'Bassador',
#  'Basset-Fauve-de-Bretagne',
#  'Basset-Hound',
#  'Basset-Retriever',
#  'Bavarian-Mountain-Scent-Hound',
#  'Beabull',
#  'Beagle',
#  'Beaglier',
#  'Bearded-Collie',
#  'Bedlington-Terrier',
#  'Belgian-Malinois',
#  'Belgian-Sheepdog',
#  'Belgian-Tervuren',
#  'Bergamasco-Sheepdog',
#  'Berger-Picard',
#  'Bernedoodle',
#  'Bernese-Mountain-Dog',
#  'Bichon-Frise',
#  'Biewer-Terrier',
#  'Black-and-Tan-Coonhound',
#  'Black-Mouth-Cur',
#  'Black-Russian-Terrier',
#  'Bloodhound',
#  'Blue-Lacy',
#  'Bluetick-Coonhound',
#  'Bocker',
#  'Boerboel',
#  'Boglen-Terrier',
#  'Bohemian-Shepherd',
#  'Bolognese',
#  'Borador',
#  'Border-Collie',
#  'Border-Sheepdog',
#  'Border-Terrier',
#  'Bordoodle',
#  'Borzoi',
#  'BoShih',
#  'Bossie',
#  'Boston-Boxer',
#  'Boston-Terrier',
#  'Boston-Terrier-Pekingese-Mix',
#  'Bouvier-des-Flandres',
#  'Boxador',
#  'Boxer',
#  'Boxerdoodle',
#  'Boxmatian',
#  'Boxweiler',
#  'Boykin-Spaniel',
#  'Bracco-Italiano',
#  'Braque-du-Bourbonnais',
#  'Briard',
#  'Brittany',
#  'Broholmer',
#  'Brussels-Griffon',
#  'Bugg',
#  'Bull-Pei',
#  'Bull-Terrier',
#  'Bullador',
#  'Bullboxer-Pit',
#  'Bulldog',
#  'Bullmastiff',
#  'Bullmatian',
#  'Cairn-Terrier',
#  'Canaan-Dog',
#  'Cane-Corso',
#  'Cardigan-Welsh-Corgi',
#  'Carolina-Dog',
#  'Catahoula-Bulldog',
#  'Catahoula-Leopard-Dog',
#  'Caucasian-Shepherd-Dog',
#  'Cav-a-Jack',
#  'Cavachon',
#  'Cavador',
#  'Cavalier-King-Charles-Spaniel',
#  'Cavapoo',
#  'Central-Asian-Shepherd-Dog',
#  'Cesky-Terrier',
#  'Chabrador',
#  'Cheagle',
#  'Chesapeake-Bay-Retriever',
#  'Chi-Chi',
#  'Chi-Poo',
#  'Chigi',
#  'Chihuahua',
#  'Chilier',
#  'Chinese-Crested',
#  'Chinese-Shar-Pei',
#  'Chinook',
#  'Chion',
#  'Chipin',
#  'Chiweenie',
#  'Chorkie',
#  'Chow-Chow',
#  'Chow-Shepherd',
#  'Chug',
#  'Chusky',
#  'Cirneco-dell’Etna',
#  'Clumber-Spaniel',
#  'Cockalier',
#  'Cockapoo',
#  'Cocker-Spaniel',
#  'Collie',
#  'Corgi-Inu',
#  'Corgidor',
#  'Corman-Shepherd',
#  'Coton-de-Tulear',
#  'Croatian-Sheepdog',
#  'Curly-Coated-Retriever',
#  'Dachsador',
#  'Dachshund',
#  'Dalmatian',
#  'Dandie-Dinmont-Terrier',
#  'Daniff',
#  'Danish-Swedish-Farmdog',
#  'Deutscher-Wachtelhund',
#  'Doberdor',
#  'Doberman-Pinscher',
#  'Docker',
#  'Dogo-Argentino',
#  'Dogue-de-Bordeaux',
#  'Dorgi',
#  'Dorkie',
#  'Doxiepoo',
#  'Doxle',
#  'Drentsche-Patrijshond',
#  'Drever',
#  'Dutch-Shepherd',
#  'English-Cocker-Spaniel',
#  'English-Foxhound',
#  'English-Setter',
#  'English-Springer-Spaniel',
#  'English-Toy-Spaniel',
#  'Entlebucher-Mountain-Dog',
#  'Estrela-Mountain-Dog',
#  'Eurasier',
#  'Field-Spaniel',
#  'Fila-Brasileiro',
#  'Finnish-Lapphund',
#  'Finnish-Spitz',
#  'Flat-Coated-Retriever',
#  'Fox-Terrier',
#  'French-Bulldog',
#  'French-Bullhuahua',
#  'French-Spaniel',
#  'Frenchton',
#  'Frengle',
#  'German-Longhaired-Pointer',
#  'German-Pinscher',
#  'German-Shepherd-Dog',
#  'German-Shepherd-Pit-Bull',
#  'German-Shepherd-Rottweiler-Mix',
#  'German-Sheprador',
#  'German-Shorthaired-Pointer',
#  'German-Spitz',
#  'German-Wirehaired-Pointer',
#  'Giant-Schnauzer',
#  'Glen-of-Imaal-Terrier',
#  'Goberian',
#  'Goldador',
#  'Golden-Cocker-Retriever',
#  'Golden-Mountain-Dog',
#  'Golden-Retriever',
#  'Golden-Retriever-Corgi',
#  'Golden-Shepherd',
#  'Goldendoodle',
#  'Gollie',
#  'Gordon-Setter',
#  'Great-Dane',
#  'Great-Pyrenees',
#  'Greater-Swiss-Mountain-Dog',
#  'Greyador',
#  'Greyhound',
#  'Hamiltonstovare',
#  'Hanoverian-Scenthound',
#  'Harrier',
#  'Havanese',
#  'Hokkaido',
#  'Horgi',
#  'Hovawart',
#  'Huskita',
#  'Huskydoodle',
#  'Ibizan-Hound',
#  'Icelandic-Sheepdog',
#  'Irish-Red-And-White-Setter',
#  'Irish-Setter',
#  'Irish-Terrier',
#  'Irish-Water-Spaniel',
#  'Irish-Wolfhound',
#  'Italian-Greyhound',
#  'Jack-A-Poo',
#  'Jack-Chi',
#  'Jack-Russell-Terrier',
#  'Jackshund',
#  'Japanese-Chin',
#  'Japanese-Spitz',
#  'Korean-Jindo-Dog',
#  'Kai-Ken',
#  'Karelian-Bear-Dog',
#  'Keeshond',
#  'Kerry-Blue-Terrier',
#  'King-Shepherd',
#  'Kishu-Ken',
#  'Komondor',
#  'Kooikerhondje',
#  'Kuvasz',
#  'Kyi-Leo',
#  'Lab-Pointer',
#  'Labernese',
#  'Labmaraner',
#  'Labrabull',
#  'Labradane',
#  'Labradoodle',
#  'Labrador-Retriever',
#  'Labrastaff',
#  'Labsky',
#  'Lagotto-Romagnolo',
#  'Lakeland-Terrier',
#  'Lancashire-Heeler',
#  'Leonberger',
#  'Lhasa-Apso',
#  'Lhasapoo',
#  'Lowchen',
#  'Maltese',
#  'Maltese-Shih-Tzu',
#  'Maltipoo',
#  'Manchester-Terrier',
#  'Mastador',
#  'Mastiff',
#  'Miniature-Pinscher',
#  'Miniature-Schnauzer',
#  'Morkie',
#  'Mudi',
#  'Mutt-(Mixed)',
#  'Neapolitan-Mastiff',
#  'Newfoundland',
#  'Norfolk-Terrier',
#  'Northern-Inuit-Dog',
#  'Norwegian-Buhund',
#  'Norwegian-Elkhound',
#  'Norwegian-Lundehund',
#  'Norwich-Terrier',
#  'Nova-Scotia-Duck-Tolling-Retriever',
#  'Old-English-Sheepdog',
#  'Otterhound',
#  'Papillon',
#  'Papipoo',
#  'Patterdale-Terrier',
#  'Peekapoo',
#  'Pekingese',
#  'Pembroke-Welsh-Corgi',
#  'Petit-Basset-Griffon-Vendéen',
#  'Pharaoh-Hound',
#  'Pitsky',
#  'Plott',
#  'Pocket-Beagle',
#  'Pointer',
#  'Polish-Lowland-Sheepdog',
#  'Pomapoo',
#  'Pomchi',
#  'Pomeagle',
#  'Pomeranian',
#  'Pomsky',
#  'Poochon',
#  'Poodle',
#  'Portuguese-Podengo-Pequeno',
#  'Portuguese-Sheepdog',
#  'Portuguese-Water-Dog',
#  'Pug',
#  'Pugalier',
#  'Puggle',
#  'Puginese',
#  'Puli',
#  'Pyredoodle',
#  'Pyrenean-Mastiff',
#  'Pyrenean-Shepherd',
#  'Rat-Terrier',
#  'Redbone-Coonhound',
#  'Rhodesian-Ridgeback',
#  'Rottador',
#  'Rottle',
#  'Rottweiler',
#  'Saint-Berdoodle',
#  'Saint-Bernard',
#  'Saluki',
#  'Samoyed',
#  'Samusky',
#  'Schipperke',
#  'Schnoodle',
#  'Scottish-Deerhound',
#  'Scottish-Terrier',
#  'Sealyham-Terrier',
#  'Sheepadoodle',
#  'Shepsky',
#  'Shetland-Sheepdog',
#  'Shiba-Inu',
#  'Shichon',
#  'Shih-Poo',
#  'Shih-Tzu',
#  'Shiloh-Shepherd',
#  'Shiranian',
#  'Shollie',
#  'Shorkie',
#  'Siberian-Husky',
#  'Silken-Windhound',
#  'Silky-Terrier',
#  'Skye-Terrier',
#  'Sloughi',
#  'Small-Munsterlander-Pointer',
#  'Soft-Coated-Wheaten-Terrier',
#  'Spanish-Mastiff',
#  'Spinone-Italiano',
#  'Springador',
#  'Stabyhoun',
#  'Staffordshire-Bull-Terrier',
#  'Staffy-Bull-Bullmastiff',
#  'Standard-Schnauzer',
#  'Sussex-Spaniel',
#  'Swedish-Lapphund',
#  'Swedish-Vallhund',
#  'Taiwan-Dog',
#  'Terripoo',
#  'Texas-Heeler',
#  'Tibetan-Mastiff',
#  'Tibetan-Spaniel',
#  'Tibetan-Terrier',
#  'Toy-Fox-Terrier',
#  'Transylvanian-Hound',
#  'Treeing-Tennessee-Brindle',
#  'Treeing-Walker-Coonhound',
#  'Valley-Bulldog',
#  'Vizsla',
#  'Weimaraner',
#  'Welsh-Springer-Spaniel',
#  'Welsh-Terrier',
#  'West-Highland-White-Terrier',
#  'Westiepoo',
#  'Whippet',
#  'Whoodle',
#  'Wirehaired-Pointing-Griffon',
#  'Xoloitzcuintli',
#  'Yorkipoo',
#  'Yorkshire-Terrier']

# %%
'''now that we that have a list of dogs, we will loop through them and get the attributes and rankings for each of them.

We need to ensure that a url exists for the dog breed'''
# Out:
# 'now that we that have a list of dogs, we will loop through them and get the attributes and rankings for each of them.\n\nWe need to ensure that a url exists for the dog breed'

# %%
list_of_attributes = []

for dog in dog_list:
    row = []
    row.append(dog)
    print(dog)
    url = get_url(dog)
    series = get_attributes(url)
    for rank in series:
        row.append(rank)
    list_of_attributes.append(row)
    
list_of_attributes
# Out:
# Afador
# Affenhuahua
# Affenpinscher
# Afghan-Hound
# Airedale-Terrier
# Akbash
# Akita
# Akita-Chow
# Akita-Pit
# Akita-Shepherd
# Alaskan-Klee-Kai
# Alaskan-Malamute
# American-Bulldog
# American-English-Coonhound
# American-Eskimo-Dog
# American-Foxhound
# American-Hairless-Terrier
# American-Leopard-Hound
# American-Pit-Bull-Terrier
# American-Pugabull
# American-Staffordshire-Terrier
# American-Water-Spaniel
# Anatolian-Shepherd-Dog
# Appenzeller-Sennenhunde
# Auggie
# Aussiedoodle
# Aussiepom
# Australian-Cattle-Dog
# Australian-Kelpie
# Australian-Retriever
# Australian-Shepherd
# Australian-Shepherd-Husky
# Australian-Shepherd-Lab-Mix
# Australian-Shepherd-Pit-Bull-Mix
# Australian-Stumpy-Tail-Cattle-Dog
# Australian-Terrier
# Azawakh
# Barbet
# Basenji
# Bassador
# Basset-Fauve-de-Bretagne
# Basset-Hound
# Basset-Retriever
# Bavarian-Mountain-Scent-Hound
# Beabull
# Beagle
# Beaglier
# Bearded-Collie
# Bedlington-Terrier
# Belgian-Malinois
# Belgian-Sheepdog
# Belgian-Tervuren
# Bergamasco-Sheepdog
# Berger-Picard
# Bernedoodle
# Bernese-Mountain-Dog
# Bichon-Frise
# Biewer-Terrier
# Black-and-Tan-Coonhound
# Black-Mouth-Cur
# Black-Russian-Terrier
# Bloodhound
# Blue-Lacy
# Bluetick-Coonhound
# Bocker
# Boerboel
# Boglen-Terrier
# Bohemian-Shepherd
# Bolognese
# Borador
# Border-Collie
# Border-Sheepdog
# Border-Terrier
# Bordoodle
# Borzoi
# BoShih
# Bossie
# Boston-Boxer
# Boston-Terrier
# Boston-Terrier-Pekingese-Mix
# Bouvier-des-Flandres
# Boxador
# Boxer
# Boxerdoodle
# Boxmatian
# Boxweiler
# Boykin-Spaniel
# Bracco-Italiano
# Braque-du-Bourbonnais
# Briard
# Brittany
# Broholmer
# Brussels-Griffon
# Bugg
# Bull-Pei
# Bull-Terrier
# Bullador
# Bullboxer-Pit
# Bulldog
# Bullmastiff
# Bullmatian
# Cairn-Terrier
# Canaan-Dog
# Cane-Corso
# Cardigan-Welsh-Corgi
# Carolina-Dog
# Catahoula-Bulldog
# Catahoula-Leopard-Dog
# Caucasian-Shepherd-Dog
# Cav-a-Jack
# Cavachon
# Cavador
# Cavalier-King-Charles-Spaniel
# Cavapoo
# Central-Asian-Shepherd-Dog
# Cesky-Terrier
# Chabrador
# Cheagle
# Chesapeake-Bay-Retriever
# Chi-Chi
# Chi-Poo
# Chigi
# Chihuahua
# Chilier
# Chinese-Crested
# Chinese-Shar-Pei
# Chinook
# Chion
# Chipin
# Chiweenie
# Chorkie
# Chow-Chow
# Chow-Shepherd
# Chug
# Chusky
# Cirneco-dell’Etna
# Clumber-Spaniel
# Cockalier
# Cockapoo
# Cocker-Spaniel
# Collie
# Corgi-Inu
# Corgidor
# Corman-Shepherd
# Coton-de-Tulear
# Croatian-Sheepdog
# Curly-Coated-Retriever
# Dachsador
# Dachshund
# Dalmatian
# Dandie-Dinmont-Terrier
# Daniff
# Danish-Swedish-Farmdog
# Deutscher-Wachtelhund
# Doberdor
# Doberman-Pinscher
# Docker
# Dogo-Argentino
# Dogue-de-Bordeaux
# Dorgi
# Dorkie
# Doxiepoo
# Doxle
# Drentsche-Patrijshond
# Drever
# Dutch-Shepherd
# English-Cocker-Spaniel
# English-Foxhound
# English-Setter
# English-Springer-Spaniel
# English-Toy-Spaniel
# Entlebucher-Mountain-Dog
# Estrela-Mountain-Dog
# Eurasier
# Field-Spaniel
# Fila-Brasileiro
# Finnish-Lapphund
# Finnish-Spitz
# Flat-Coated-Retriever
# Fox-Terrier
# French-Bulldog
# French-Bullhuahua
# French-Spaniel
# Frenchton
# Frengle
# German-Longhaired-Pointer
# German-Pinscher
# German-Shepherd-Dog
# German-Shepherd-Pit-Bull
# German-Shepherd-Rottweiler-Mix
# German-Sheprador
# German-Shorthaired-Pointer
# German-Spitz
# German-Wirehaired-Pointer
# Giant-Schnauzer
# Glen-of-Imaal-Terrier
# Goberian
# Goldador
# Golden-Cocker-Retriever
# Golden-Mountain-Dog
# Golden-Retriever
# Golden-Retriever-Corgi
# Golden-Shepherd
# Goldendoodle
# Gollie
# Gordon-Setter
# Great-Dane
# Great-Pyrenees
# Greater-Swiss-Mountain-Dog
# Greyador
# Greyhound
# Hamiltonstovare
# Hanoverian-Scenthound
# Harrier
# Havanese
# Hokkaido
# Horgi
# Hovawart
# Huskita
# Huskydoodle
# Ibizan-Hound
# Icelandic-Sheepdog
# Irish-Red-And-White-Setter
# Irish-Setter
# Irish-Terrier
# Irish-Water-Spaniel
# Irish-Wolfhound
# Italian-Greyhound
# Jack-A-Poo
# Jack-Chi
# Jack-Russell-Terrier
# Jackshund
# Japanese-Chin
# Japanese-Spitz
# Korean-Jindo-Dog
# Kai-Ken
# Karelian-Bear-Dog
# Keeshond
# Kerry-Blue-Terrier
# King-Shepherd
# Kishu-Ken
# Komondor
# Kooikerhondje
# Kuvasz
# Kyi-Leo
# Lab-Pointer
# Labernese
# Labmaraner
# Labrabull
# Labradane
# Labradoodle
# Labrador-Retriever
# Labrastaff
# Labsky
# Lagotto-Romagnolo
# Lakeland-Terrier
# Lancashire-Heeler
# Leonberger
# Lhasa-Apso
# Lhasapoo
# Lowchen
# Maltese
# Maltese-Shih-Tzu
# Maltipoo
# Manchester-Terrier
# Mastador
# Mastiff
# Miniature-Pinscher
# Miniature-Schnauzer
# Morkie
# Mudi
# Mutt-(Mixed)
# Neapolitan-Mastiff
# Newfoundland
# Norfolk-Terrier
# Northern-Inuit-Dog
# Norwegian-Buhund
# Norwegian-Elkhound
# Norwegian-Lundehund
# Norwich-Terrier
# Nova-Scotia-Duck-Tolling-Retriever
# Old-English-Sheepdog
# Otterhound
# Papillon
# Papipoo
# Patterdale-Terrier
# Peekapoo
# Pekingese
# Pembroke-Welsh-Corgi
# Petit-Basset-Griffon-Vendéen
# Pharaoh-Hound
# Pitsky
# Plott
# Pocket-Beagle
# Pointer
# Polish-Lowland-Sheepdog
# Pomapoo
# Pomchi
# Pomeagle
# Pomeranian
# Pomsky
# Poochon
# Poodle
# Portuguese-Podengo-Pequeno
# Portuguese-Sheepdog
# Portuguese-Water-Dog
# Pug
# Pugalier
# Puggle
# Puginese
# Puli
# Pyredoodle
# Pyrenean-Mastiff
# Pyrenean-Shepherd
# Rat-Terrier
# Redbone-Coonhound
# Rhodesian-Ridgeback
# Rottador
# Rottle
# Rottweiler
# Saint-Berdoodle
# Saint-Bernard
# Saluki
# Samoyed
# Samusky
# Schipperke
# Schnoodle
# Scottish-Deerhound
# Scottish-Terrier
# Sealyham-Terrier
# Sheepadoodle
# Shepsky
# Shetland-Sheepdog
# Shiba-Inu
# Shichon
# Shih-Poo
# Shih-Tzu
# Shiloh-Shepherd
# Shiranian
# Shollie
# Shorkie
# Siberian-Husky
# Silken-Windhound
# Silky-Terrier
# Skye-Terrier
# Sloughi
# Small-Munsterlander-Pointer
# Soft-Coated-Wheaten-Terrier
# Spanish-Mastiff
# Spinone-Italiano
# Springador
# Stabyhoun
# Staffordshire-Bull-Terrier
# Staffy-Bull-Bullmastiff
# Standard-Schnauzer
# Sussex-Spaniel
# Swedish-Lapphund
# Swedish-Vallhund
# Taiwan-Dog
# Terripoo
# Texas-Heeler
# Tibetan-Mastiff
# Tibetan-Spaniel
# Tibetan-Terrier
# Toy-Fox-Terrier
# Transylvanian-Hound
# Treeing-Tennessee-Brindle
# Treeing-Walker-Coonhound
# Valley-Bulldog
# Vizsla
# Weimaraner
# Welsh-Springer-Spaniel
# Welsh-Terrier
# West-Highland-White-Terrier
# Westiepoo
# Whippet
# Whoodle
# Wirehaired-Pointing-Griffon
# Xoloitzcuintli
# Yorkipoo
# Yorkshire-Terrier
# [['Afador', '2', '3', '3', '4', '4'],
#  ['Affenhuahua', '3', '3', '3', '3', '3'],
#  ['Affenpinscher', '3', '3', '2', '3', '4'],
#  ['Afghan-Hound', '4', '4', '2', '3', '4'],
#  ['Airedale-Terrier', '2', '4', '3', '5', '5'],
#  ['Akbash', '3', '4', '4', '3', '2'],
#  ['Akita', '3', '2', '4', '4', '4'],
#  ['Akita-Chow', '3', '1', '3', '3', '4'],
#  ['Akita-Pit', '3', '3', '4', '3', '3'],
#  ['Akita-Shepherd', '3', '3', '3', '3', '3'],
#  ['Alaskan-Klee-Kai', '3', '3', '3', '4', '4'],
#  ['Alaskan-Malamute', '2', '4', '3', '4', '5'],
#  ['American-Bulldog', '2', '3', '3', '3', '4'],
#  ['American-English-Coonhound', '3', '5', '3', '5', '5'],
#  ['American-Eskimo-Dog', '4', '5', '3', '4', '4'],
#  ['American-Foxhound', '2', '5', '4', '4', '5'],
#  ['American-Hairless-Terrier', '3', '4', '3', '3', '4'],
#  ['American-Leopard-Hound', '3', '4', '3', '4', '4'],
#  ['American-Pit-Bull-Terrier', '3', '4', '3', '4', '5'],
#  ['American-Pugabull', '3', '4', '3', '3', '4'],
#  ['American-Staffordshire-Terrier', '2', '4', '3', '4', '4'],
#  ['American-Water-Spaniel', '3', '4', '3', '4', '4'],
#  ['Anatolian-Shepherd-Dog', '3', '2', '3', '3', '3'],
#  ['Appenzeller-Sennenhunde', '3', '4', '3', '4', '4'],
#  ['Auggie', '3', '5', '3', '4', '5'],
#  ['Aussiedoodle', '3', '4', '4', '4', '5'],
#  ['Aussiepom', '3', '4', '3', '3', '4'],
#  ['Australian-Cattle-Dog', '3', '4', '3', '4', '5'],
#  ['Australian-Kelpie', '3', '3', '3', '5', '4'],
#  ['Australian-Retriever', '3', '4', '3', '3', '4'],
#  ['Australian-Shepherd', '3', '4', '2', '5', '5'],
#  ['Australian-Shepherd-Husky', '3', '3', '3', '4', '5'],
#  ['Australian-Shepherd-Lab-Mix', '4', '4', '4', '4', '5'],
#  ['Australian-Shepherd-Pit-Bull-Mix', '3', '4', '4', '3', '4'],
#  ['Australian-Stumpy-Tail-Cattle-Dog', '3', '3', '3', '3', '4'],
#  ['Australian-Terrier', '3', '3', '3', '4', '5'],
#  ['Azawakh', '3', '3', '3', '3', '3'],
#  ['Barbet', '3', '4', '2', '3', '4'],
#  ['Basenji', '4', '5', '2', '4', '3'],
#  ['Bassador', '3', '3', '4', '3', '3'],
#  ['Basset-Fauve-de-Bretagne', '3', '4', '3', '3', '3'],
#  ['Basset-Hound', '3', '5', '4', '4', '2'],
#  ['Basset-Retriever', '3', '4', '3', '4', '4'],
#  ['Bavarian-Mountain-Scent-Hound', '2', '4', '3', '3', '4'],
#  ['Beabull', '3', '4', '4', '4', '4'],
#  ['Beagle', '3', '5', '3', '4', '5'],
#  ['Beaglier', '3', '5', '3', '3', '4'],
#  ['Bearded-Collie', '3', '5', '3', '4', '4'],
#  ['Bedlington-Terrier', '4', '5', '3', '4', '4'],
#  ['Belgian-Malinois', '3', '4', '3', '4', '5'],
#  ['Belgian-Sheepdog', '4', '5', '3', '4', '5'],
#  ['Belgian-Tervuren', '3', '3', '3', '4', '4'],
#  ['Bergamasco-Sheepdog', '3', '4', '3', '3', '3'],
#  ['Berger-Picard', '4', '4', '4', '3', '5'],
#  ['Bernedoodle', '3', '4', '3', '4', '4'],
#  ['Bernese-Mountain-Dog', '2', '5', '4', '4', '4'],
#  ['Bichon-Frise', '4', '5', '2', '3', '4'],
#  ['Biewer-Terrier', '3', '4', '2', '3', '4'],
#  ['Black-and-Tan-Coonhound', '3', '5', '4', '4', '5'],
#  ['Black-Mouth-Cur', '3', '4', '3', '4', '4'],
#  ['Black-Russian-Terrier', '3', '3', '3', '3', '4'],
#  ['Bloodhound', '3', '5', '3', '4', '4'],
#  ['Blue-Lacy', '3', '3', '3', '5', '5'],
#  ['Bluetick-Coonhound', '3', '4', '3', '4', '5'],
#  ['Bocker', '4', '4', '3', '5', '4'],
#  ['Boerboel', '2', '3', '4', '3', '4'],
#  ['Boglen-Terrier', '3', '5', '3', '4', '5'],
#  ['Bohemian-Shepherd', '3', '4', '3', '3', '4'],
#  ['Bolognese', '3', '5', '2', '4', '3'],
#  ['Borador', '3', '4', '4', '3', '4'],
#  ['Border-Collie', '3', '4', '3', '4', '5'],
#  ['Border-Sheepdog', '3', '4', '3', '4', '4'],
#  ['Border-Terrier', '3', '4', '3', '4', '5'],
#  ['Bordoodle', '4', '4', '3', '3', '3'],
#  ['Borzoi', '4', '4', '4', '4', '2'],
#  ['BoShih', '3', '3', '3', '2', '3'],
#  ['Bossie', '3', '4', '3', '4', '5'],
#  ['Boston-Boxer', '3', '4', '4', '3', '4'],
#  ['Boston-Terrier', '4', '5', '3', '3', '5'],
#  ['Boston-Terrier-Pekingese-Mix', '3', '4', '3', '3', '3'],
#  ['Bouvier-des-Flandres', '3', '4', '3', '3', '4'],
#  ['Boxador', '2', '4', '4', '4', '5'],
#  ['Boxer', '3', '4', '3', '3', '5'],
#  ['Boxerdoodle', '3', '4', '3', '3', '4'],
#  ['Boxmatian', '2', '3', '4', '4', '5'],
#  ['Boxweiler', '3', '4', '3', '3', '4'],
#  ['Boykin-Spaniel', '3', '4', '3', '4', '5'],
#  ['Bracco-Italiano', '3', '4', '3', '3', '4'],
#  ['Braque-du-Bourbonnais', '2', '4', '3', '3', '4'],
#  ['Briard', '3', '4', '2', '4', '4'],
#  ['Brittany', '3', '5', '4', '4', '5'],
#  ['Broholmer', '3', '4', '4', '3', '3'],
#  ['Brussels-Griffon', '3', '4', '3', '3', '4'],
#  ['Bugg', '3', '3', '3', '3', '3'],
#  ['Bull-Pei', '2', '2', '4', '2', '2'],
#  ['Bull-Terrier', '3', '5', '3', '4', '5'],
#  ['Bullador', '2', '4', '4', '4', '4'],
#  ['Bullboxer-Pit', '2', '3', '4', '4', '5'],
#  ['Bulldog', '3', '4', '4', '2', '3'],
#  ['Bullmastiff', '3', '4', '4', '3', '4'],
#  ['Bullmatian', '2', '4', '3', '3', '4'],
#  ['Cairn-Terrier', '4', '5', '3', '4', '5'],
#  ['Canaan-Dog', '4', '3', '3', '3', '4'],
#  ['Cane-Corso', '2', '3', '4', '4', '4'],
#  ['Cardigan-Welsh-Corgi', '4', '4', '3', '4', '3'],
#  ['Carolina-Dog', '3', '3', '4', '3', '4'],
#  ['Catahoula-Bulldog', '2', '3', '3', '3', '5'],
#  ['Catahoula-Leopard-Dog', '2', '3', '3', '3', '4'],
#  ['Caucasian-Shepherd-Dog', '3', '3', '4', '3', '3'],
#  ['Cav-a-Jack', '3', '4', '3', '4', '4'],
#  ['Cavachon', '4', '5', '3', '3', '4'],
#  ['Cavador', '3', '4', '3', '3', '4'],
#  ['Cavalier-King-Charles-Spaniel', '4', '5', '3', '3', '4'],
#  ['Cavapoo', '3', '5', '3', '3', '3'],
#  ['Central-Asian-Shepherd-Dog', '3', '3', '4', '3', '3'],
#  ['Cesky-Terrier', '4', '3', '3', '3', '3'],
#  ['Chabrador', '3', '3', '4', '3', '4'],
#  ['Cheagle', '3', '3', '3', '3', '4'],
#  ['Chesapeake-Bay-Retriever', '3', '3', '4', '3', '5'],
#  ['Chi-Chi', '3', '3', '3', '3', '4'],
#  ['Chi-Poo', '4', '4', '2', '4', '3'],
#  ['Chigi', '3', '4', '3', '3', '4'],
#  ['Chihuahua', '3', '4', '2', '3', '3'],
#  ['Chilier', '3', '4', '3', '3', '4'],
#  ['Chinese-Crested', '3', '4', '2', '3', '2'],
#  ['Chinese-Shar-Pei', '3', '2', '3', '3', '2'],
#  ['Chinook', '3', '5', '3', '3', '3'],
#  ['Chion', '3', '3', '3', '3', '3'],
#  ['Chipin', '3', '3', '3', '3', '4'],
#  ['Chiweenie', '3', '3', '3', '3', '4'],
#  ['Chorkie', '3', '3', '2', '3', '4'],
#  ['Chow-Chow', '3', '1', '3', '2', '2'],
#  ['Chow-Shepherd', '3', '3', '3', '3', '5'],
#  ['Chug', '3', '4', '3', '3', '4'],
#  ['Chusky', '3', '4', '3', '3', '4'],
#  ['Cirneco-dell’Etna'],
#  ['Clumber-Spaniel', '4', '4', '4', '4', '3'],
#  ['Cockalier', '3', '4', '3', '3', '4'],
#  ['Cockapoo', '4', '5', '2', '3', '4'],
#  ['Cocker-Spaniel', '4', '4', '3', '4', '3'],
#  ['Collie', '4', '5', '3', '3', '3'],
#  ['Corgi-Inu', '3', '3', '3', '3', '4'],
#  ['Corgidor', '3', '4', '4', '3', '4'],
#  ['Corman-Shepherd', '3', '4', '3', '3', '4'],
#  ['Coton-de-Tulear', '4', '5', '2', '3', '3'],
#  ['Croatian-Sheepdog', '3', '3', '3', '4', '4'],
#  ['Curly-Coated-Retriever', '3', '4', '3', '4', '4'],
#  ['Dachsador', '3', '4', '3', '3', '4'],
#  ['Dachshund', '3', '3', '3', '4', '3'],
#  ['Dalmatian', '3', '4', '4', '3', '5'],
#  ['Dandie-Dinmont-Terrier', '3', '4', '2', '3', '3'],
#  ['Daniff', '3', '4', '3', '3', '4'],
#  ['Danish-Swedish-Farmdog', '3', '5', '3', '4', '4'],
#  ['Deutscher-Wachtelhund', '3', '4', '3', '3', '4'],
#  ['Doberdor', '2', '3', '3', '3', '5'],
#  ['Doberman-Pinscher', '3', '3', '4', '3', '4'],
#  ['Docker', '3', '3', '3', '4', '3'],
#  ['Dogo-Argentino', '2', '3', '3', '3', '4'],
#  ['Dogue-de-Bordeaux', '3', '3', '4', '3', '3'],
#  ['Dorgi', '3', '4', '3', '3', '4'],
#  ['Dorkie', '3', '4', '2', '3', '2'],
#  ['Doxiepoo', '3', '3', '2', '4', '4'],
#  ['Doxle', '3', '5', '3', '4', '5'],
#  ['Drentsche-Patrijshond', '3', '4', '3', '3', '4'],
#  ['Drever', '3', '4', '3', '3', '4'],
#  ['Dutch-Shepherd', '3', '4', '3', '3', '4'],
#  ['English-Cocker-Spaniel', '4', '5', '3', '4', '4'],
#  ['English-Foxhound', '3', '4', '3', '4', '5'],
#  ['English-Setter', '3', '5', '3', '4', '4'],
#  ['English-Springer-Spaniel', '3', '5', '3', '4', '5'],
#  ['English-Toy-Spaniel', '3', '4', '3', '3', '3'],
#  ['Entlebucher-Mountain-Dog', '3', '4', '3', '4', '5'],
#  ['Estrela-Mountain-Dog', '3', '4', '3', '3', '3'],
#  ['Eurasier', '3', '4', '3', '2', '3'],
#  ['Field-Spaniel', '3', '5', '3', '4', '5'],
#  ['Fila-Brasileiro', '2', '2', '4', '3', '4'],
#  ['Finnish-Lapphund', '4', '5', '3', '4', '5'],
#  ['Finnish-Spitz', '3', '5', '3', '4', '5'],
#  ['Flat-Coated-Retriever', '3', '5', '3', '4', '5'],
#  ['Fox-Terrier', '3', '4', '2', '4', '5'],
#  ['French-Bulldog', '3', '4', '3', '3', '4'],
#  ['French-Bullhuahua', '3', '3', '3', '3', '3'],
#  ['French-Spaniel', '3', '4', '3', '3', '4'],
#  ['Frenchton', '4', '5', '3', '3', '4'],
#  ['Frengle', '3', '5', '3', '3', '4'],
#  ['German-Longhaired-Pointer', '3', '4', '4', '3', '4'],
#  ['German-Pinscher', '3', '3', '3', '4', '5'],
#  ['German-Shepherd-Dog', '3', '4', '4', '4', '5'],
#  ['German-Shepherd-Pit-Bull', '2', '5', '4', '4', '5'],
#  ['German-Shepherd-Rottweiler-Mix', '3', '4', '4', '3', '4'],
#  ['German-Sheprador', '3', '5', '4', '4', '5'],
#  ['German-Shorthaired-Pointer', '2', '4', '3', '5', '5'],
#  ['German-Spitz', '3', '4', '3', '4', '4'],
#  ['German-Wirehaired-Pointer', '3', '3', '3', '4', '5'],
#  ['Giant-Schnauzer', '2', '3', '3', '4', '4'],
#  ['Glen-of-Imaal-Terrier', '3', '4', '3', '4', '4'],
#  ['Goberian', '3', '4', '3', '3', '5'],
#  ['Goldador', '4', '5', '3', '3', '5'],
#  ['Golden-Cocker-Retriever', '3', '4', '3', '3', '4'],
#  ['Golden-Mountain-Dog', '2', '4', '4', '3', '4'],
#  ['Golden-Retriever', '3', '5', '4', '4', '4'],
#  ['Golden-Retriever-Corgi', '3', '5', '3', '3', '4'],
#  ['Golden-Shepherd', '3', '5', '3', '4', '5'],
#  ['Goldendoodle', '3', '5', '3', '3', '4'],
#  ['Gollie', '3', '5', '3', '3', '4'],
#  ['Gordon-Setter', '3', '3', '3', '4', '4'],
#  ['Great-Dane', '2', '5', '4', '3', '5'],
#  ['Great-Pyrenees', '3', '4', '4', '4', '5'],
#  ['Greater-Swiss-Mountain-Dog', '3', '5', '3', '3', '4'],
#  ['Greyador', '3', '5', '5', '4', '4'],
#  ['Greyhound', '3', '5', '5', '4', '4'],
#  ['Hamiltonstovare', '3', '4', '3', '3', '4'],
#  ['Hanoverian-Scenthound', '3', '4', '3', '3', '4'],
#  ['Harrier', '3', '5', '3', '4', '5'],
#  ['Havanese', '4', '5', '2', '3', '3'],
#  ['Hokkaido', '3', '4', '3', '3', '3'],
#  ['Horgi', '3', '5', '3', '4', '4'],
#  ['Hovawart', '3', '3', '3', '2', '4'],
#  ['Huskita', '3', '3', '3', '4', '5'],
#  ['Huskydoodle', '3', '4', '3', '3', '5'],
#  ['Ibizan-Hound', '3', '5', '3', '4', '5'],
#  ['Icelandic-Sheepdog', '3', '3', '3', '3', '4'],
#  ['Irish-Red-And-White-Setter', '3', '4', '2', '4', '5'],
#  ['Irish-Setter', '3', '5', '3', '5', '5'],
#  ['Irish-Terrier', '3', '4', '3', '3', '5'],
#  ['Irish-Water-Spaniel', '3', '5', '2', '4', '4'],
#  ['Irish-Wolfhound', '2', '5', '3', '3', '3'],
#  ['Italian-Greyhound', '3', '5', '3', '4', '4'],
#  ['Jack-A-Poo', '4', '5', '2', '4', '5'],
#  ['Jack-Chi', '3', '4', '3', '3', '4'],
#  ['Jack-Russell-Terrier', '3', '5', '3', '4', '5'],
#  ['Jackshund', '3', '4', '3', '5', '4'],
#  ['Japanese-Chin', '3', '3', '2', '3', '2'],
#  ['Japanese-Spitz', '3', '4', '3', '3', '3'],
#  ['Korean-Jindo-Dog'],
#  ['Kai-Ken', '3', '3', '3', '3', '4'],
#  ['Karelian-Bear-Dog', '3', '3', '3', '4', '4'],
#  ['Keeshond', '4', '5', '3', '3', '4'],
#  ['Kerry-Blue-Terrier', '3', '4', '2', '4', '4'],
#  ['King-Shepherd', '4', '4', '4', '3', '4'],
#  ['Kishu-Ken', '3', '3', '3', '3', '3'],
#  ['Komondor', '3', '3', '3', '4', '3'],
#  ['Kooikerhondje', '3', '2', '3', '3', '5'],
#  ['Kuvasz', '3', '2', '4', '2', '4'],
#  ['Kyi-Leo', '4', '4', '2', '3', '3'],
#  ['Lab-Pointer', '3', '4', '3', '4', '4'],
#  ['Labernese', '3', '4', '3', '3', '4'],
#  ['Labmaraner', '3', '4', '3', '4', '4'],
#  ['Labrabull', '3', '4', '4', '4', '5'],
#  ['Labradane', '3', '4', '4', '3', '4'],
#  ['Labradoodle', '4', '5', '3', '3', '5'],
#  ['Labrador-Retriever', '3', '5', '4', '4', '5'],
#  ['Labrastaff', '3', '4', '4', '3', '4'],
#  ['Labsky', '2', '4', '3', '4', '5'],
#  ['Lagotto-Romagnolo', '3', '3', '2', '3', '4'],
#  ['Lakeland-Terrier', '3', '4', '3', '3', '4'],
#  ['Lancashire-Heeler', '3', '3', '3', '3', '4'],
#  ['Leonberger', '2', '4', '4', '3', '4'],
#  ['Lhasa-Apso', '4', '3', '2', '3', '4'],
#  ['Lhasapoo', '3', '3', '3', '3', '4'],
#  ['Lowchen', '3', '5', '3', '4', '4'],
#  ['Maltese', '3', '4', '2', '3', '3'],
#  ['Maltese-Shih-Tzu', '3', '3', '2', '4', '3'],
#  ['Maltipoo', '4', '4', '2', '4', '3'],
#  ['Manchester-Terrier', '3', '3', '3', '3', '4'],
#  ['Mastador', '3', '4', '4', '3', '4'],
#  ['Mastiff', '2', '4', '4', '2', '4'],
#  ['Miniature-Pinscher', '3', '3', '3', '4', '4'],
#  ['Miniature-Schnauzer', '4', '4', '2', '4', '4'],
#  ['Morkie', '3', '3', '2', '4', '4'],
#  ['Mudi', '3', '3', '3', '4', '4'],
#  ['Mutt-(Mixed)'],
#  ['Neapolitan-Mastiff', '2', '3', '4', '2', '3'],
#  ['Newfoundland', '3', '5', '4', '4', '3'],
#  ['Norfolk-Terrier', '4', '5', '3', '3', '4'],
#  ['Northern-Inuit-Dog', '3', '4', '3', '4', '5'],
#  ['Norwegian-Buhund', '3', '4', '3', '3', '5'],
#  ['Norwegian-Elkhound', '4', '4', '3', '4', '4'],
#  ['Norwegian-Lundehund', '3', '5', '3', '3', '5'],
#  ['Norwich-Terrier', '4', '5', '3', '4', '5'],
#  ['Nova-Scotia-Duck-Tolling-Retriever', '4', '5', '3', '4', '5'],
#  ['Old-English-Sheepdog', '4', '4', '3', '3', '4'],
#  ['Otterhound', '3', '5', '3', '4', '5'],
#  ['Papillon', '3', '4', '2', '3', '4'],
#  ['Papipoo', '4', '4', '2', '3', '5'],
#  ['Patterdale-Terrier', '3', '4', '3', '4', '4'],
#  ['Peekapoo', '4', '4', '2', '3', '3'],
#  ['Pekingese', '3', '3', '2', '4', '2'],
#  ['Pembroke-Welsh-Corgi', '4', '4', '3', '4', '4'],
#  ['Petit-Basset-Griffon-Vendéen'],
#  ['Pharaoh-Hound', '4', '5', '3', '4', '3'],
#  ['Pitsky', '2', '5', '3', '4', '5'],
#  ['Plott', '2', '4', '3', '4', '4'],
#  ['Pocket-Beagle', '3', '5', '3', '4', '4'],
#  ['Pointer', '2', '5', '3', '5', '5'],
#  ['Polish-Lowland-Sheepdog', '4', '4', '2', '3', '4'],
#  ['Pomapoo', '3', '4', '2', '3', '3'],
#  ['Pomchi', '3', '3', '3', '4', '4'],
#  ['Pomeagle', '3', '4', '3', '3', '4'],
#  ['Pomeranian', '3', '3', '3', '3', '3'],
#  ['Pomsky', '3', '3', '3', '4', '3'],
#  ['Poochon', '4', '5', '2', '3', '4'],
#  ['Poodle', '4', '5', '2', '4', '4'],
#  ['Portuguese-Podengo-Pequeno', '3', '4', '3', '4', '4'],
#  ['Portuguese-Sheepdog', '3', '4', '3', '3', '4'],
#  ['Portuguese-Water-Dog', '3', '5', '2', '4', '5'],
#  ['Pug', '3', '4', '3', '2', '4'],
#  ['Pugalier', '4', '5', '3', '3', '4'],
#  ['Puggle', '4', '5', '3', '3', '3'],
#  ['Puginese', '4', '3', '3', '2', '3'],
#  ['Puli', '3', '4', '2', '4', '5'],
#  ['Pyredoodle', '3', '4', '3', '4', '4'],
#  ['Pyrenean-Mastiff', '3', '3', '4', '3', '4'],
#  ['Pyrenean-Shepherd', '3', '4', '2', '3', '5'],
#  ['Rat-Terrier', '3', '4', '3', '4', '5'],
#  ['Redbone-Coonhound', '3', '4', '3', '4', '5'],
#  ['Rhodesian-Ridgeback', '3', '4', '4', '3', '5'],
#  ['Rottador', '3', '4', '4', '4', '5'],
#  ['Rottle', '3', '4', '3', '3', '4'],
#  ['Rottweiler', '2', '4', '4', '4', '4'],
#  ['Saint-Berdoodle', '3', '5', '3', '3', '3'],
#  ['Saint-Bernard', '3', '5', '4', '2', '3'],
#  ['Saluki', '2', '4', '3', '4', '4'],
#  ['Samoyed', '3', '5', '3', '4', '4'],
#  ['Samusky', '3', '4', '3', '3', '4'],
#  ['Schipperke', '3', '3', '3', '3', '5'],
#  ['Schnoodle', '3', '4', '3', '3', '4'],
#  ['Scottish-Deerhound', '3', '4', '3', '3', '5'],
#  ['Scottish-Terrier', '3', '4', '2', '3', '4'],
#  ['Sealyham-Terrier', '4', '4', '3', '3', '4'],
#  ['Sheepadoodle', '4', '5', '3', '3', '4'],
#  ['Shepsky', '3', '4', '3', '4', '5'],
#  ['Shetland-Sheepdog', '3', '5', '3', '3', '4'],
#  ['Shiba-Inu', '4', '3', '3', '4', '3'],
#  ['Shichon', '3', '5', '3', '2', '4'],
#  ['Shih-Poo', '3', '4', '2', '3', '3'],
#  ['Shih-Tzu', '3', '5', '2', '3', '3'],
#  ['Shiloh-Shepherd', '3', '5', '4', '4', '4'],
#  ['Shiranian', '3', '4', '2', '2', '3'],
#  ['Shollie', '3', '3', '3', '4', '4'],
#  ['Shorkie', '3', '3', '2', '3', '4'],
#  ['Siberian-Husky', '3', '5', '3', '4', '5'],
#  ['Silken-Windhound', '4', '4', '3', '4', '4'],
#  ['Silky-Terrier', '3', '3', '3', '4', '4'],
#  ['Skye-Terrier', '4', '4', '3', '4', '4'],
#  ['Sloughi', '3', '4', '3', '3', '4'],
#  ['Small-Munsterlander-Pointer', '3', '5', '3', '4', '5'],
#  ['Soft-Coated-Wheaten-Terrier', '3', '5', '3', '3', '4'],
#  ['Spanish-Mastiff', '3', '3', '3', '2', '3'],
#  ['Spinone-Italiano', '4', '5', '3', '3', '4'],
#  ['Springador', '3', '3', '3', '4', '4'],
#  ['Stabyhoun', '3', '4', '3', '4', '4'],
#  ['Staffordshire-Bull-Terrier', '2', '4', '3', '3', '4'],
#  ['Staffy-Bull-Bullmastiff', '2', '3', '3', '2', '2'],
#  ['Standard-Schnauzer', '3', '3', '2', '4', '5'],
#  ['Sussex-Spaniel', '4', '5', '3', '3', '2'],
#  ['Swedish-Lapphund', '3', '4', '3', '4', '4'],
#  ['Swedish-Vallhund', '3', '4', '4', '3', '5'],
#  ['Taiwan-Dog', '3', '3', '3', '4', '4'],
#  ['Terripoo', '3', '4', '2', '4', '4'],
#  ['Texas-Heeler', '3', '3', '3', '4', '4'],
#  ['Tibetan-Mastiff', '3', '4', '3', '3', '3'],
#  ['Tibetan-Spaniel', '3', '4', '3', '4', '4'],
#  ['Tibetan-Terrier', '4', '4', '2', '3', '5'],
#  ['Toy-Fox-Terrier', '3', '4', '3', '4', '5'],
#  ['Transylvanian-Hound', '3', '3', '3', '3', '4'],
#  ['Treeing-Tennessee-Brindle', '2', '4', '4', '3', '4'],
#  ['Treeing-Walker-Coonhound', '3', '4', '4', '4', '4'],
#  ['Valley-Bulldog', '3', '4', '4', '3', '4'],
#  ['Vizsla', '3', '5', '3', '4', '5'],
#  ['Weimaraner', '3', '4', '4', '4', '5'],
#  ['Welsh-Springer-Spaniel', '4', '4', '3', '4', '5'],
#  ['Welsh-Terrier', '3', '5', '3', '4', '5'],
#  ['West-Highland-White-Terrier', '4', '4', '3', '4', '4'],
#  ['Westiepoo', '3', '4', '3', '4', '4'],
#  ['Whippet', '3', '5', '3', '4', '4'],
#  ['Whoodle', '3', '4', '3', '2', '4'],
#  ['Wirehaired-Pointing-Griffon', '3', '5', '3', '4', '4'],
#  ['Xoloitzcuintli'],
#  ['Yorkipoo', '4', '4', '2', '4', '4'],
#  ['Yorkshire-Terrier', '3', '3', '2', '3', '5']]

# %%
'''create dataframe with titles as column headings'''
titles.insert(0,'Breed')
dog_df = pd.DataFrame(list_of_attributes, columns=titles)

# %%
dog_df = dog_df.set_index('Breed')
print(dog_df.shape)
dog_df
# Out:
# (381, 5)
#                             Adaptability All Around Friendliness  \
# Breed
# Afador                                 2                       3
# Affenhuahua                            3                       3
# Affenpinscher                          3                       3
# Afghan-Hound                           4                       4
# Airedale-Terrier                       2                       4
# ...                                  ...                     ...
# Whoodle                                3                       4
# Wirehaired-Pointing-Griffon            3                       5
# Xoloitzcuintli                      None                    None
# Yorkipoo                               4                       4
# Yorkshire-Terrier                      3                       3
#
#                             Health And Grooming Needs Trainability  \
# Breed
# Afador                                              3            4
# Affenhuahua                                         3            3
# Affenpinscher                                       2            3
# Afghan-Hound                                        2            3
# Airedale-Terrier                                    3            5
# ...                                               ...          ...
# Whoodle                                             3            2
# Wirehaired-Pointing-Griffon                         3            4
# Xoloitzcuintli                                   None         None
# Yorkipoo                                            2            4
# Yorkshire-Terrier                                   2            3
#
#                             Physical Needs
# Breed
# Afador                                   4
# Affenhuahua                              3
# Affenpinscher                            4
# Afghan-Hound                             4
# Airedale-Terrier                         5
# ...                                    ...
# Whoodle                                  4
# Wirehaired-Pointing-Griffon              4
# Xoloitzcuintli                        None
# Yorkipoo                                 4
# Yorkshire-Terrier                        5
#
# [381 rows x 5 columns]

# %%
dog_df.to_csv('Dog_Breeds_With_Rankings.csv')

# %%
"""Now we have a completed dataframe with over 350 dog breeds and rankings for 5 categories that will help us later rank these dogs based on a variety of things that an owner is looking for in a dog.

This is saved to the file 'Dog_Breeds_With_Rankings.csv' that we will use later on"""
# Out:
# "Now we have a completed dataframe with over 350 dog breeds and rankings for 5 categories that will help us later rank these dogs based on a variety of things that an owner is looking for in a dog.\n\nThis is saved to the file 'Dog_Breeds_With_Rankings.csv' that we will use later on"
